// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Plant{
    protected string Name {get; set;}
    protected string Type {get; set;}
    protected int Size {get; set;}

    protected Plant(string name, string type, int size) {
        Name = name;
        Type = type;
        Size = size;
    }

    public virtual void Bloom (){
        Console.WriteLine("Растение цветёт");
    }

    public void IncreaseSize(int size){
        Size += size;
        Console.WriteLine($"Растение увеличилось на {size}. Общий размер растения: {Size}");
    }
}


public class Flower : Plant { 
    private string Color {get; set;}
    private int CountOfPetals {get; set;}

    public Flower(string name, string type, int size, string color, int countOfPetals) : base (name, type, size){
        Color = color;
        CountOfPetals = countOfPetals;
    }

    public override void Bloom(){
        Console.WriteLine($"Цветок {Name} распускается и радует глаз!");
    }


    public void Withering(){
        Console.WriteLine("Растение увядает");
    }
}


public class Tree : Plant { 
    private string LeafType {get; set;}
    private int Age {get; set;}

    public Tree(string name, string type, int size, string leafType, int age) : base (name, type, size){
        Age = age;
        LeafType = leafType;
    }

    public override void Bloom(){
        Console.WriteLine($"Дерево {Name} покрывается новыми листьями!");
    }


    public void Grow(int age){
        Age += age;
        Console.WriteLine($"У дерева новый возраст: {Age}");
    }
}


//Демонстрация использования
Flower flower = new Flower("Роза", "Лепестковые", 6, "красный", 8);
flower.Bloom();
flower.Withering();
flower.IncreaseSize(6);

Console.WriteLine();

Tree tree = new Tree("Дуб", "деревообразные", 90, "Каплеобразные", 5);
tree.Bloom();
tree.Grow(6);
tree.IncreaseSize(97);
// Out:
// Цветок Роза распускается и радует глаз!
// Растение увядает
// Растение увеличилось на 6. Общий размер растения: 12
//
// Дерево Дуб покрывается новыми листьями!
// У дерева новый возраст: 11
// Растение увеличилось на 97. Общий размер растения: 187
